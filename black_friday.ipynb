# %% [markdown]
# # Black Friday Dataset EDA And Feature Engineering
# #Cleaning and preparing the data for model training

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Problem Statement
# A retail company “ABC Private Limited” wants to understand the customer purchase behaviour (specifically, purchase amount) against various products of different categories. They have shared purchase summary of various customers for selected high volume products from last month. The data set also contains customer demographics (age, gender, marital status, city_type, stay_in_current_city), product details (product_id and product category) and Total purchase_amount from last month.
#
# Now, they want to build a model to predict the purchase amount of customer against various products which will help them to create personalized offer for customers against different products.

# %%
df_train = pd.read_csv('train.csv')
df_train.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
df_test = pd.read_csv('test.csv')
df_test.head()
# Out:
#    User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0  1000004  P00128942      M  46-50           7             B
# 1  1000009  P00113442      M  26-35          17             C
# 2  1000010  P00288442      F  36-45           1             B
# 3  1000010  P00145342      F  36-45           1             B
# 4  1000011  P00053842      F  26-35           1             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               1                   1
# 1                          0               0                   3
# 2                         4+               1                   5
# 3                         4+               1                   4
# 4                          1               0                   4
#
#    Product_Category_2  Product_Category_3
# 0                11.0                 NaN
# 1                 5.0                 NaN
# 2                14.0                 NaN
# ...

# %%
# Assuming you have df_train and df_test DataFrames
df = pd.concat([df_train, df_test])
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 233594  1006036  P00118942      F  26-35          15             B
# 233595  1006036  P00254642      F  26-35          15             B
# 233596  1006036  P00031842      F  26-35          15             B
# 233597  1006037  P00124742      F  46-50           1             C
# 233598  1006039  P00316642      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
#basic code
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 783667 entries, 0 to 233598
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     783667 non-null  int64
#  1   Product_ID                  783667 non-null  object
#  2   Gender                      783667 non-null  object
#  3   Age                         783667 non-null  object
#  4   Occupation                  783667 non-null  int64
#  5   City_Category               783667 non-null  object
#  6   Stay_In_Current_City_Years  783667 non-null  object
#  7   Marital_Status              783667 non-null  int64
#  8   Product_Category_1          783667 non-null  int64
#  9   Product_Category_2          537685 non-null  float64
#  10  Product_Category_3          237858 non-null  float64
#  11  Purchase                    550068 non-null  float64
# dtypes: float64(3), int64(4), object(5)
# ...

# %%
df.describe() #To find out percentile value
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  7.836670e+05  783667.000000   783667.000000       783667.000000
# mean   1.003029e+06       8.079300        0.409777            5.366196
# std    1.727267e+03       6.522206        0.491793            3.878160
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001519e+06       2.000000        0.000000            1.000000
# 50%    1.003075e+06       7.000000        0.000000            5.000000
# 75%    1.004478e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           20.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       537685.000000       237858.000000  550068.000000
# mean             9.844506           12.668605    9263.968713
# std              5.089093            4.125510    5023.065394
# min              2.000000            3.000000      12.000000
# ...

# %%
df.drop(['User_ID'],axis=1,inplace=True)

# %%
df.head()
# Out:
#   Product_ID Gender   Age  Occupation City_Category  \
# 0  P00069042      F  0-17          10             A
# 1  P00248942      F  0-17          10             A
# 2  P00087842      F  0-17          10             A
# 3  P00085442      F  0-17          10             A
# 4  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# 2                 NaN                 NaN    1422.0
# ...

# %%
#categorical into numerical
pd.get_dummies(df['Gender'],drop_first=1)
# Out:
#             M
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
# ...       ...
# 233594  False
# 233595  False
# 233596  False
# 233597  False
# 233598  False
#
# [783667 rows x 1 columns]

# %%
#Handling categorical feature
df['Gender'] = df['Gender'].map({'F': 0, 'M': 1})
df.head()
# Out:
#   Product_ID  Gender   Age  Occupation City_Category  \
# 0  P00069042       0  0-17          10             A
# 1  P00248942       0  0-17          10             A
# 2  P00087842       0  0-17          10             A
# 3  P00085442       0  0-17          10             A
# 4  P00285442       1   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# 2                 NaN                 NaN    1422.0
# ...

# %%
##Handling categorical feature Age
df['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
#df['Age']=pd.get_dummies(df['Age'],drop_first=True)

# %%
#label encoding will also work


# Define a dictionary to map age ranges to numerical values
age_mapping = {
    '0-17': 1,
    '18-25': 2,
    '26-35': 3,
    '36-45': 4,
    '46-50': 5,
    '51-55': 6,
    '55+': 7
}

# Use the map function with a lambda function to handle inconsistencies
df['Age'] = df['Age'].map(lambda x: age_mapping.get(x, -1))

# Replace any remaining -1 values with a default value (e.g., 0)
df['Age'].replace(-1, 0, inplace=True)

# %%
age_mapping = {
    '0-17': 1,
    '18-25': 2,
    '26-53': 3,
    '36-45': 4,
    '46-55': 5,
    '51-55': 6,
    '55+': 6,
    'your_actual_value_1': your_corresponding_numeric_value_1,
    'your_actual_value_2': your_corresponding_numeric_value_2,
    # Add more mappings as needed
}

df['Age'] = df['Age'].map(age_mapping)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 9
#       1 age_mapping = {
#       2     '0-17': 1,
#       3     '18-25': 2,
#       4     '26-53': 3,
#       5     '36-45': 4,
#       6     '46-55': 5,
#       7     '51-55': 6,
#       8     '55+': 6,
# ----> 9     'your_actual_value_1': your_corresponding_numeric_value_1,
#      10     'your_actual_value_2': your_corresponding_numeric_value_2,
#      11     # Add more mappings as needed
#      12 }
#      14 df['Age'] = df['Age'].map(age_mapping)
#
# NameError: name 'your_corresponding_numeric_value_1' is not defined

# %%
your_corresponding_numeric_value_1 = 7
your_corresponding_numeric_value_2 = 8

age_mapping = {
    '0-17': 1,
    '18-25': 2,
    '26-53': 3,
    '36-45': 4,
    '46-55': 5,
    '51-55': 6,
    '55+': 6,
    'your_actual_value_1': your_corresponding_numeric_value_1,
    'your_actual_value_2': your_corresponding_numeric_value_2,
    # Add more mappings as needed
}

df['Age'] = df['Age'].map(age_mapping)

# %%
print(df['Age'].unique())
# Out:
# [nan]

# %%
#second Technique

from sklearn import preprocessing

label_encoder = preprocessing.LabelEncoder()

df['Age']=label_encoder.fit_transform(df['Age'])

df['Age'].unique()
# Out:
# array([0], dtype=int64)

# %%
df.head(70)
# Out:
#    Product_ID  Gender  Age  Occupation City_Category  \
# 0   P00069042       0    0          10             A
# 1   P00248942       0    0          10             A
# 2   P00087842       0    0          10             A
# 3   P00085442       0    0          10             A
# 4   P00285442       1    0          16             C
# ..        ...     ...  ...         ...           ...
# 65  P00244242       0    0           0             C
# 66  P00217742       0    0           0             C
# 67  P00019342       1    0           1             C
# 68  P00100642       1    0           1             C
# 69  P00073842       1    0           1             C
#
#    Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                           2               0                   3
# 1                           2               0                   1
# 2                           2               0                  12
# ...

# %%
df_city=pd.get_dummies(['City_Category'],drop_first=True)

# %%
df_city.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [0]
